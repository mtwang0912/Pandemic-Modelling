# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

Node_number = [100,1000,10000,50000,100000,200000,300000]

# Control Variables: 
#family_weight = 0.5
#stranger_weight = 0.2
#x_value = 6  
#prob_of_infection = 0.
#number of edges new node attaches to = 2

#prob = prob_of_infection * prob_of_infection_weighted

Node_100_time_1 = [16, 20, 14, 12, 17]
Node_1000_time_1 = [22, 24, 27, 20, 20]
Node_10000_time_1 = [27, 34, 22, 28, 32]
Node_50000_time_1 = [33, 32, 35, 33, 32]
Node_100000_time_1 = [31, 35, 28, 31, 35]
Node_200000_time_1 = [37, 35, 34, 31, 37]
Node_300000_time_1 = [44, 42, 37, 35, 32]

#prob = prob_of_infection * random.uniform(0, 1)

Node_100_time_2 = [12, 11, 10, 11, 12]
Node_1000_time_2 = [15, 14, 14, 21, 13]
Node_10000_time_2 = [20, 16, 18, 19, 19]
Node_50000_time_2 = [23, 21, 22, 21, 22]
Node_100000_time_2 = [22, 20, 22, 20, 22]
Node_200000_time_2 = [22, 24, 22, 22, 25]
Node_300000_time_2 = [27, 23, 25, 22, 21]

timestep_0_unw = [np.mean(Node_100_time_2), np.mean(Node_1000_time_2),
                  np.mean(Node_10000_time_2), np.mean(Node_50000_time_2), np.mean(Node_100000_time_2),
                  np.mean(Node_200000_time_2), np.mean(Node_300000_time_2)]

timestep_0_unw_err = [np.std(Node_100_time_2), np.std(Node_1000_time_2), np.std(Node_10000_time_2),
                      np.std(Node_50000_time_2), np.std(Node_100000_time_2), np.std(Node_200000_time_2),
                      np.std(Node_300000_time_2)]

timestep_0_w = [np.mean(Node_100_time_1), np.mean(Node_1000_time_1),
                np.mean(Node_10000_time_1), np.mean(Node_50000_time_1), np.mean(Node_100000_time_1),
                np.mean(Node_200000_time_1), np.mean(Node_300000_time_1)]

timestep_0_w_err = [np.std(Node_100_time_1), np.std(Node_1000_time_1), np.std(Node_10000_time_1),
                    np.std(Node_50000_time_1), np.std(Node_100000_time_1), np.std(Node_200000_time_1),
                    np.std(Node_300000_time_1)]


# plt.savefig('pendulum_dpi_300_small.png')
# plt.close()

#

# Control Variables: 
#family_weight = 0.8
#stranger_weight = 0.2
#x_value = 6  
#prob_of_infection = 0.8
#number of edges new node attaches to = 2
#FAMILY WEIGHT CHANGED

#prob = prob_of_infection * prob_of_infection_weighted

Node_100_time_3 = [27, 25, 18, 24, 29]
Node_1000_time_3 = [32, 26, 42, 29, 32]
Node_10000_time_3 = [32, 38, 40, 39, 42]
Node_50000_time_3 = [43, 41, 52, 38, 53]
Node_100000_time_3 = [43, 53, 52, 52, 47]
Node_200000_time_3 = [48, 44, 64, 61, 57]
Node_300000_time_3 = [56, 53, 51, 56, 50]

#prob = prob_of_infection * random.uniform(0, 1)

Node_100_time_4 = [12, 10, 10, 13, 12]
Node_1000_time_4 = [18, 14, 13, 16, 18]
Node_10000_time_4 = [16, 18, 18, 17, 20]
Node_50000_time_4 = [23, 22, 19, 20, 22]
Node_100000_time_4 = [21, 21, 24, 27, 22]
Node_200000_time_4 = [23, 23, 22, 24, 23]
Node_300000_time_4 = [24, 25, 25, 24, 22]

timestep_1_w = [np.mean(Node_100_time_3),np.mean(Node_1000_time_3),
      np.mean(Node_10000_time_3),np.mean(Node_50000_time_3),np.mean(Node_100000_time_3), 
      np.mean(Node_200000_time_3), np.mean(Node_300000_time_3)]

timestep_1_w_err = [np.std(Node_100_time_3),np.std(Node_1000_time_3),np.std(Node_10000_time_3)
                      ,np.std(Node_50000_time_3),np.std(Node_100000_time_3),np.std(Node_200000_time_3),
                      np.std(Node_300000_time_3)]


timestep_1_unw = [np.mean(Node_100_time_4),np.mean(Node_1000_time_4),
      np.mean(Node_10000_time_4),np.mean(Node_50000_time_4),np.mean(Node_100000_time_4), 
      np.mean(Node_200000_time_4), np.mean(Node_300000_time_4)]

timestep_1_unw_err = [np.std(Node_100_time_4), np.std(Node_1000_time_4), np.std(Node_10000_time_4),
                      np.std(Node_50000_time_4), np.std(Node_100000_time_4), np.std(Node_200000_time_4),
                      np.std(Node_300000_time_4)]


# Control Variables: 
#family_weight = 0.95
#stranger_weight = 0.2
#x_value = 6  
#prob_of_infection = 0.8
#number of edges new node attaches to = 2
#FAMILY WEIGHT CHANGED

#prob = prob_of_infection * prob_of_infection_weighted

Node_100_time_5 = [10, 11, 10, 9, 14]
Node_1000_time_5 = [14, 14, 12, 16, 15]
Node_10000_time_5 = [19, 18, 20, 19, 22]
Node_50000_time_5 = [20, 23, 19, 22, 21]
Node_100000_time_5 = [22, 19, 21, 25, 22]
Node_200000_time_5 = [22, 22, 21, 25, 25]
Node_300000_time_5 = [24, 24, 22, 26, 21]

# Control Variables: 
#family_weight = 0.6
#stranger_weight = 0.2
#x_value = 6  
#prob_of_infection = 0.8
#number of edges new node attaches to = 2
#FAMILY WEIGHT CHANGED

#prob = prob_of_infection * prob_of_infection_weighted

Node_100_time_6 = [18, 16, 15, 14, 22]
Node_1000_time_6 = [32, 27, 26, 24, 24]
Node_10000_time_6 = [30, 29, 32, 38, 40]
Node_50000_time_6 = [35, 41, 39, 36, 37]
Node_100000_time_6 = [38, 36, 36, 34, 42]
Node_200000_time_6 = [37, 39, 40, 47, 39]
Node_300000_time_6 = [44, 43, 38, 40, 41]

# Control Variables: 
#family_weight = 0.4
#stranger_weight = 0.2
#x_value = 6  
#prob_of_infection = 0.8
#number of edges new node attaches to = 2
#FAMILY WEIGHT CHANGED


Node_100_time_7 = [13, 13, 15, 9, 18]
Node_1000_time_7 = [16, 22, 18, 16, 14]
Node_10000_time_7 = [24, 24, 26, 22, 23]
Node_50000_time_7 =  [28, 27, 26, 29, 28]
Node_100000_time_7 =  [32, 29, 34, 29, 28]
Node_200000_time_7 = [29, 29, 29, 33, 30]
Node_300000_time_7 =[32, 33, 33, 32, 29]



timestep_1_w = [np.mean(Node_100_time_3),np.mean(Node_1000_time_3),
      np.mean(Node_10000_time_3),np.mean(Node_50000_time_3),np.mean(Node_100000_time_3), 
      np.mean(Node_200000_time_3), np.mean(Node_300000_time_3)]

timestep_1_w_err = [np.std(Node_100_time_3),np.std(Node_1000_time_3),np.std(Node_10000_time_3)
                      ,np.std(Node_50000_time_3),np.std(Node_100000_time_3),np.std(Node_200000_time_3),
                      np.std(Node_300000_time_3)]

timestep_1_unw = [np.mean(Node_100_time_4),np.mean(Node_1000_time_4),
      np.mean(Node_10000_time_4),np.mean(Node_50000_time_4),np.mean(Node_100000_time_4), 
      np.mean(Node_200000_time_4), np.mean(Node_300000_time_4)]

timestep_1_unw_err = [np.std(Node_100_time_4), np.std(Node_1000_time_4), np.std(Node_10000_time_4),
                      np.std(Node_50000_time_4), np.std(Node_100000_time_4), np.std(Node_200000_time_4),
                      np.std(Node_300000_time_4)]



timestep_0_unw = [np.mean(Node_100_time_2), np.mean(Node_1000_time_2),
                  np.mean(Node_10000_time_2), np.mean(Node_50000_time_2), np.mean(Node_100000_time_2),
                  np.mean(Node_200000_time_2), np.mean(Node_300000_time_2)]

timestep_0_unw_err = [np.std(Node_100_time_2), np.std(Node_1000_time_2), np.std(Node_10000_time_2),
                      np.std(Node_50000_time_2), np.std(Node_100000_time_2), np.std(Node_200000_time_2),
                      np.std(Node_300000_time_2)]

timestep_2_w = [np.mean(Node_100_time_5), np.mean(Node_1000_time_5),
                  np.mean(Node_10000_time_5), np.mean(Node_50000_time_5), np.mean(Node_100000_time_5),
                  np.mean(Node_200000_time_5), np.mean(Node_300000_time_5)]

timestep_2_w_err = [np.std(Node_100_time_5), np.std(Node_1000_time_5), np.std(Node_10000_time_5),
                      np.std(Node_50000_time_5), np.std(Node_100000_time_5), np.std(Node_200000_time_5),
                      np.std(Node_300000_time_5)]


timestep_0_unw = [np.mean(Node_100_time_2), np.mean(Node_1000_time_2),
                  np.mean(Node_10000_time_2), np.mean(Node_50000_time_2), np.mean(Node_100000_time_2),
                  np.mean(Node_200000_time_2), np.mean(Node_300000_time_2)]

timestep_0_unw_err = [np.std(Node_100_time_2), np.std(Node_1000_time_2), np.std(Node_10000_time_2),
                      np.std(Node_50000_time_2), np.std(Node_100000_time_2), np.std(Node_200000_time_2),
                      np.std(Node_300000_time_2)]

timestep_3_w = [np.mean(Node_100_time_6), np.mean(Node_1000_time_6),
                  np.mean(Node_10000_time_6), np.mean(Node_50000_time_6), np.mean(Node_100000_time_6),
                  np.mean(Node_200000_time_6), np.mean(Node_300000_time_6)]

timestep_3_w_err = [np.std(Node_100_time_6), np.std(Node_1000_time_6), np.std(Node_10000_time_6),
                      np.std(Node_50000_time_6), np.std(Node_100000_time_6), np.std(Node_200000_time_6),
                      np.std(Node_300000_time_6)]

timestep_4_w = [np.mean(Node_100_time_7), np.mean(Node_1000_time_7),
                  np.mean(Node_10000_time_7), np.mean(Node_50000_time_7), np.mean(Node_100000_time_7),
                  np.mean(Node_200000_time_7), np.mean(Node_300000_time_7)]

timestep_4_w_err = [np.std(Node_100_time_7), np.std(Node_1000_time_7), np.std(Node_10000_time_7),
                      np.std(Node_50000_time_7), np.std(Node_100000_time_7), np.std(Node_200000_time_7),
                      np.std(Node_300000_time_7)]


def plot(unweighted, unweighted_error, weighted, weighted_error, family_weights):
    fig = plt.figure(figsize=(3, 2), dpi=500)
    ax = fig.add_subplot(111)
    ax.grid()

    ax.errorbar(unweighted, Node_number, xerr=unweighted_error, fmt='.', label='Unweighted', color='orange',
                capsize=1, ms=1, elinewidth=1, capthick=1)
    ax.errorbar(weighted, Node_number, xerr=weighted_error, fmt='.', label='Weighted', color='red',
                capsize=1, ms=1, elinewidth=1, capthick=1)
    ax.set_ylim(0, 400000)
    ax.set_xlabel('Timestep', fontsize=8)
    ax.set_ylabel('Total Number of Nodes', fontsize=8)

    # Change the title based on the family_weights array
    family_weight_value = np.mean(family_weights)  # You can choose any method to determine the value
    ax.set_title(f'Family Weight = {family_weight_value}', fontsize=10)

    ax.plot(unweighted, Node_number, "--", color='orange', alpha=0.5, linewidth=0.7)
    ax.plot(weighted, Node_number, "--", color='red', alpha=0.5, linewidth=0.7)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[::-1], labels[::-1], loc='upper left', fontsize=6, framealpha=1)
    ax.tick_params(axis='both', labelsize=6, direction='in', top=True, right=True, which='both')

    ax.xaxis.set_minor_locator(MultipleLocator(2))
    ax.yaxis.set_minor_locator(MultipleLocator(10000))

    return fig.tight_layout()


plot(timestep_0_unw,timestep_0_unw_err,timestep_1_w,timestep_1_w_err, 0.8)
plot(timestep_0_unw,timestep_0_unw_err,timestep_2_w,timestep_2_w_err, 0.95)
plot(timestep_0_unw,timestep_0_unw_err,timestep_3_w,timestep_3_w_err, 0.6)
plot(timestep_0_unw,timestep_0_unw_err,timestep_3_w,timestep_3_w_err, 0.4)

# %%
# Control Variables: 
#family_weight = 0.6
#x_value = 6  
#prob_of_infection = 0.8
#number of edges new node attaches to = 2
#x_value = 6


#Independent Variable: stranger_weight
#STRANGER WEIGHT CHANGED


#unweighted

Node_100_s_unw_0 =[11, 12, 11, 10, 13]
Node_1000_s_unw_0 = [14, 17, 12, 14, 17]
Node_10000_s_unw_0 =  [17, 18, 16, 20, 20]
Node_50000_s_unw_0 = [21, 26, 19, 21, 25]
Node_100000_s_unw_0 = [23, 22, 23, 22, 23]
Node_200000_s_unw_0 = [22, 24, 25, 23, 20]
Node_300000_s_unw_0 = [23, 22, 23, 22, 24]


#weighted
#stranger_weight = 0.4

Node_100_s_w_0 = [13, 14, 10, 10, 17]
Node_1000_s_w_0 = [16, 16, 15, 18, 16]
Node_10000_s_w_0 = [21, 23, 23, 24, 19]
Node_50000_s_w_0 = [28, 26, 24, 20, 23]
Node_100000_s_w_0 = [23, 26, 27, 27, 28]
Node_200000_s_w_0 = [24, 27, 31, 26, 27]
Node_300000_s_w_0 = [28, 30, 29, 27, 25]


#weighted
#stranger_weight = 0.5

Node_100_s_w_1 = [12, 11, 11, 14, 11]
Node_1000_s_w_1 = [18, 16, 14, 16, 15]
Node_10000_s_w_1 = [18, 20, 20, 17, 19]
Node_50000_s_w_1 = [19, 22, 23, 23, 28]
Node_100000_s_w_1 = [23, 27, 22, 23, 25]
Node_200000_s_w_1 = [22, 24, 23, 22, 25]
Node_300000_s_w_1 = [24, 23, 26, 26, 29]


#weighted

#stranger_weight = 0.6
#family_weight = 0.8

Node_100_s_w_2 = [11, 11, 17, 9, 11]
Node_1000_s_w_2 = [22, 15, 17, 16, 15]
Node_10000_s_w_2 = [20, 19, 19, 21, 22]
Node_50000_s_w_2 = [23, 22, 21, 18, 25]
Node_100000_s_w_2 = [23, 25, 24, 25, 27]
Node_200000_s_w_2 = [24, 26, 25, 21, 27]
Node_300000_s_w_2 =  [24, 22, 26, 25, 29]

#stranger_weight = 0.75
#family_weight = 0.8

Node_100_s_w_3 = [12, 11, 12, 15, 14]
Node_1000_s_w_3 = [14, 14, 16, 14, 14]
Node_10000_s_w_3 = [19, 20, 18, 17, 18]
Node_50000_s_w_3 = [22, 21, 22, 23, 22]
Node_100000_s_w_3 = [24, 22, 25, 20, 23]
Node_200000_s_w_3 = [22, 27, 25, 21, 25]
Node_300000_s_w_3 =  [27, 19, 25, 26, 25]

#stranger_weight = 0.9
#family_weight = 0.95

Node_100_s_w_4 = [13, 8, 14, 8, 10]
Node_1000_s_w_4 = [16, 17, 15, 14, 16]
Node_10000_s_w_4 = [17, 17, 18, 21, 23]
Node_50000_s_w_4 = [26, 21, 20, 21, 26]
Node_100000_s_w_4 = [23, 22, 20, 20, 25]
Node_200000_s_w_4 = [22, 22, 23, 25, 23]
Node_300000_s_w_4 =  [24, 24, 25, 26, 24]

unw = [Node_100_s_unw_0,Node_1000_s_unw_0,Node_10000_s_unw_0,Node_50000_s_unw_0,
         Node_100000_s_unw_0,Node_200000_s_unw_0,Node_300000_s_unw_0]

w_0 = [Node_100_s_w_0, Node_1000_s_w_0, Node_10000_s_w_0, Node_50000_s_w_0,
 Node_100000_s_w_0, Node_200000_s_w_0, Node_300000_s_w_0]

w_1 = [Node_100_s_w_1, Node_1000_s_w_1, Node_10000_s_w_1, Node_50000_s_w_1,
 Node_100000_s_w_1, Node_200000_s_w_1, Node_300000_s_w_1]

w_2 = [Node_100_s_w_2, Node_1000_s_w_2, Node_10000_s_w_2, Node_50000_s_w_2,
 Node_100000_s_w_2, Node_200000_s_w_2, Node_300000_s_w_2]

w_3 = [Node_100_s_w_3, Node_1000_s_w_3, Node_10000_s_w_3, Node_50000_s_w_3,
 Node_100000_s_w_3, Node_200000_s_w_3, Node_300000_s_w_3]

w_4 = [Node_100_s_w_4, Node_1000_s_w_4, Node_10000_s_w_4, Node_50000_s_w_4,
 Node_100000_s_w_4, Node_200000_s_w_4, Node_300000_s_w_4]


Node_100_s_unw_0 =[11, 12, 11, 10, 13]
Node_1000_s_unw_0 = [14, 17, 12, 14, 17]
Node_10000_s_unw_0 =  [17, 18, 16, 20, 20]
Node_50000_s_unw_0 = [21, 26, 19, 21, 25]
Node_100000_s_unw_0 = [23, 22, 23, 22, 23]
Node_200000_s_unw_0 = [22, 24, 25, 23, 20]
Node_300000_s_unw_0 = [23, 22, 23, 22, 24]

def mean(array):
    mean_array = [] 
    for i in range(len(array)):     
        mean_array.append(np.mean(array[i]))            
    return mean_array

def std(array):
    std_array = []
    for i in range(len(array)):     
        std_array.append(np.std(array[i]))            
    return std_array

def plot_2(unweighted, unweighted_error, weighted, weighted_error, family_weights, stranger_weights):
    fig = plt.figure(figsize=(3, 2), dpi=500)
    ax = fig.add_subplot(111)
    ax.grid()

    ax.errorbar(unweighted, Node_number, xerr=unweighted_error, fmt='.', label='Unweighted', color='blue',
                capsize=1, ms=1, elinewidth=1, capthick=1)
    ax.errorbar(weighted, Node_number, xerr=weighted_error, fmt='.', label='Weighted', color='green',
                capsize=1, ms=1, elinewidth=1, capthick=1)
    ax.set_ylim(0, 400000)
    ax.set_xlabel('Timestep', fontsize=8)
    ax.set_ylabel('Total Number of Nodes', fontsize=8)

    # Change the title based on the family_weights array
    family_weight_value = family_weights
    stranger_weight_value = stranger_weights
    
    # You can choose any method to determine the value
    ax.set_title(f'Family Weight = {family_weight_value}, Stranger Weight = {stranger_weight_value} ', fontsize=10)

    ax.plot(unweighted, Node_number, "--", color='blue', alpha=0.5, linewidth=0.7)
    ax.plot(weighted, Node_number, "--", color='green', alpha=0.5, linewidth=0.7)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[::-1], labels[::-1], loc='upper left', fontsize=6, framealpha=1)
    ax.tick_params(axis='both', labelsize=6, direction='in', top=True, right=True, which='both')

    ax.xaxis.set_minor_locator(MultipleLocator(2))
    ax.yaxis.set_minor_locator(MultipleLocator(10000))

    return fig.tight_layout()

plot_2(mean(unw), std(unw), mean(w_0), std(w_0),0.6, 0.4)
plot_2(mean(unw), std(unw), mean(w_1), std(w_1),0.6, 0.5)
plot_2(mean(unw), std(unw), mean(w_2), std(w_2),0.8, 0.6)
plot_2(mean(unw), std(unw), mean(w_3), std(w_3),0.8, 0.75)
plot_2(mean(unw), std(unw), mean(w_4), std(w_4),0.95, 0.8)
